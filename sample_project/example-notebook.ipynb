# %% [markdown]
# ## Heart disease project
#
# This code is about classifying whether a patient has heart disease.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart-disease.csv")

# %% [markdown]
# The following table shows heart disease information for patients.

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='target'>

# %% [markdown]
# ![](6-step-ml-framework.png)

# %%
# use ! to run shell commands
# !ls -lah
# Out:
# total 832
# drwxr-xr-x   6 klcantrell  staff   192B Jan  2 23:09 .
# drwxr-xr-x   5 klcantrell  staff   160B Jan  2 22:21 ..
# -rw-r--r--   1 klcantrell  staff   324K Jan  2 23:09 6-step-ml-framework.png
# drwxr-xr-x  11 klcantrell  staff   352B Jan  2 22:20 env
# -rw-r--r--   1 klcantrell  staff    18K Jan  2 23:12 example-notebook.ipynb
# -rw-r--r--   1 klcantrell  staff    11K Jan  2 23:03 heart-disease.csv
